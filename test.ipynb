# %%
import numpy as np 
import make_figure as mf 
import utils as utils 
import imp

# %%
imp.reload(utils)
imp.reload(mf)
# Out:
# <module 'utils' from '/home/blia/synthetic_numpy/utils.py'>

# %%
mf.get_third_figure(None)

# %%
mf.create_influence_of_shuffling_plot(None)
# Out:
# /home/blia/synthetic_numpy/make_figure.py:153: RuntimeWarning: Mean of empty slice
#   select_index = np.nanargmin([np.nanmean(mmm[-10:]) for mmm in s_error])
# array([[2.49538183e+01, 2.19546066e+01, 1.93158789e+01, ...,
#         1.02484890e-06, 1.02484890e-06, 1.02484890e-06],
#        [2.49538183e+01, 2.03247106e+01, 1.65543547e+01, ...,
#         1.08775286e-06, 1.08386358e-06, 1.07836282e-06],
#        [2.49538183e+01, 1.79219548e+01, 1.28716695e+01, ...,
#         6.48245401e-07, 6.52975651e-07, 6.49334085e-07]])
